# %% [markdown]
# # Air Quality Analysis of DIfferent Cities
#
# ## Let us understand the different colums and what mean.....
#
# ## Types of air pollution
#
# * particulate matter
# * nitrogen dioxide
# * ozone
# * sulphur dioxide
#
# ### Particular matter
#
# Particulate matter is a mix of solids and liquids, including carbon, complex organic chemicals, sulphates, nitrates, mineral dust, and water suspended in the air.
#
# PM varies in size. Some particles, such as dust, soot, dirt or smoke are large or dark enough to be seen with the naked eye. But the most damaging particles are the smaller particles, known as PM10 and PM2.5. PM10 refers to particles with a diameter smaller than 10 microns (10µm) – that’s 100 times smaller than a millimetre. PM2.5 refers to particles with a diameter smaller than 2.5 microns, and these are known as fine particles. The smallest fine particles, less than 0.1 micron in diameter, are called ultrafine particles.
#
# ### Nitrogen dioxide (NO2)
#
# Nitrogen dioxide is a gas and is a major component of urban air pollution episodes.Man-made sources of nitrogen oxides(NO), including nitrogen dioxide(NO2), are vehicles, power stations and heating. Diesel vehicles are major contributors in urban areas. Roadside levels are highest where traffic is busiest.
#
# ### Ozone (O3)
#
# Ozone is a gas composed of 3 atoms of oxygen. In the upper level of the Earth’s atmosphere, it absorbs harmful ultraviolet radiation.Near the ground, ozone is made by a chemical reaction between the sun’s rays and organic gases and oxides of nitrogen emitted by cars, power plants, chemical plants and other sources.Ozone is usually highest in the spring and summer and lowest in the winter. Ozone levels are highest during the afternoon and are often higher in the country than in towns. Ozone is a major component of summer air pollution episodes.
#
# ### Sulphur dioxide (SO2)
#
# Sulphur dioxide is a colourless gas, with a pungent, suffocating smell. It’s produced by burning sulphur-containing fuels such as coal and oil. This includes vehicles, power generation and heating.
# Most sulphur dioxide comes from electric industries that burn fossil fuels, and also from petrol refineries and cement manufacturing. It can travel over long distances and contributes to the formation of ozone.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
air_quality_df = pd.read_csv("./city_day.csv")

# %%
air_quality_df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
#air_quality_df['Date'] = pd.to_datetime(air_quality_df['Date'])

# %%
#air_quality_df.info()

# %%
air_quality_df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
air_quality_df.shape
# Out:
# (29531, 16)

# %%
air_quality_df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %% [markdown]
# Here's a summary of the functions & methods we've looked at so far:
#
# * `pd.read_csv` - Read data from a CSV file into a Pandas `DataFrame` object
# * `.info()` - View basic infomation about rows, columns & data types
# * `.describe()` - View statistical information about numeric columns
# * `.columns` - Get the list of column names
# * `.shape` - Get the number of rows & columns as a tuple

# %%
air_quality_df.City.unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %% [markdown]
# ### The cities i am thinking to select from this are
# * Hyderabad
# * Visakhapatnam
# * Delhi

# %% [markdown]
# .unique() funtion is used to get the unique values from the column

# %%
hyd_bool = air_quality_df.City =='Hyderabad'

# %%
hyd_bool
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29526    False
# 29527    False
# 29528    False
# 29529    False
# 29530    False
# Name: City, Length: 29531, dtype: bool

# %% [markdown]
# #### air_quality_df.City =='Hyderabad'
#
# * Creates a series of boll values in the City colum with a true for each row where hyberabad is present

# %%
type(hyd_bool)
# Out:
# pandas.core.series.Series

# %%
hyd_df = air_quality_df[hyd_bool]

# %% [markdown]
# ## This Creates a new Data frame for Hyderabad

# %%
hyd_df
# Out:
#             City        Date  PM2.5   PM10     NO    NO2    NOx    NH3    CO  \
# 14581  Hyderabad  2015-01-04    NaN    NaN   3.70  17.19  20.89    NaN  0.30
# 14582  Hyderabad  2015-01-05    NaN    NaN   3.61   9.69  13.30    NaN  0.23
# 14583  Hyderabad  2015-01-06    NaN    NaN   4.21  22.02  26.23    NaN  0.31
# 14584  Hyderabad  2015-01-07    NaN    NaN  26.08  40.08  66.15    NaN  0.53
# 14585  Hyderabad  2015-01-08    NaN    NaN  10.31  33.02  43.33    NaN  0.44
# ...          ...         ...    ...    ...    ...    ...    ...    ...   ...
# 16582  Hyderabad  2020-06-27  23.29  44.20   6.38  22.64  15.39   9.34  0.36
# 16583  Hyderabad  2020-06-28  15.80  32.18   5.79  22.73  14.89  11.09  0.36
# 16584  Hyderabad  2020-06-29  20.24  44.74   3.96  27.59  17.09  13.09  0.38
# 16585  Hyderabad  2020-06-30  19.38  41.95   2.63  24.58  14.59  10.80  0.39
# 16586  Hyderabad  2020-07-01  26.83  66.50   2.94  27.18  16.13   9.32  0.43
#
# ...

# %%
hyd_df.isnull()
# Out:
#         City   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 14581  False  False   True   True  False  False  False   True  False  False
# 14582  False  False   True   True  False  False  False   True  False  False
# 14583  False  False   True   True  False  False  False   True  False  False
# 14584  False  False   True   True  False  False  False   True  False  False
# 14585  False  False   True   True  False  False  False   True  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16582  False  False  False  False  False  False  False  False  False  False
# 16583  False  False  False  False  False  False  False  False  False  False
# 16584  False  False  False  False  False  False  False  False  False  False
# 16585  False  False  False  False  False  False  False  False  False  False
# 16586  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# .isnull() is used to check for null values the columns

# %%
hyd_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5         115
# PM10          355
# NO             28
# NO2            28
# NOx             7
# NH3           360
# CO              5
# SO2            26
# O3             26
# Benzene       127
# Toluene       127
# Xylene        127
# AQI           126
# AQI_Bucket    126
# dtype: int64

# %% [markdown]
# ####  .isnull().sum()-- this sums all the values in each columns

# %% [markdown]
# hyd_df.isnull().any()

# %% [markdown]
# #### .isnull().any() --> checks if there is any null value in any column and returns true for the respective columns

# %%
hyd_df.isnull().sum().sum()
# Out:
# 1583

# %% [markdown]
# #### .isnull().sum().sum() --> returns the sum of all the null values in the dataframe

# %% [markdown]
# ### Imputation using Linear Interpolation method
#
# Linear interpolation is an imputation technique that assumes a linear relationship between data points and utilises non-missing values from adjacent data points to compute a value for a missing data point.

# %%
hyd_df.interpolate(limit_direction='both',inplace=True)
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_25052\1024391676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyd_df.interpolate(limit_direction='both',inplace=True)

# %% [markdown]
# #### .interpolate(limit_direction="both", inplace=True):
# The .interpolate() method is used for data imputation.
# Data imputation is the process of filling up missing data with substitute values in a dataset
#
# It fills in missing values (NaNs) in a DataFrame by estimating values based on existing data.
#
# limit_direction="both": interpolation should happen in both forward and backward directions.
#
# inplace=True: This means that the changes made by the interpolation will be applied directly to DataFrame, modifying it in place (without creating a new DataFrame).

# %%
hyd_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5           0
# PM10            0
# NO              0
# NO2             0
# NOx             0
# NH3             0
# CO              0
# SO2             0
# O3              0
# Benzene         0
# Toluene         0
# Xylene          0
# AQI             0
# AQI_Bucket    126
# dtype: int64

# %% [markdown]
# #### Now I will repeat the procedure for all the other cites

# %%
vis_bool = air_quality_df.City =='Visakhapatnam'

# %%
vis_df = air_quality_df[vis_bool]

# %%
vis_df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 28069  Visakhapatnam  2016-07-01  44.92  82.50  16.75  56.96  40.24  62.45
# 28070  Visakhapatnam  2016-07-02    NaN    NaN    NaN    NaN    NaN    NaN
# 28071  Visakhapatnam  2016-07-03    NaN    NaN    NaN    NaN    NaN    NaN
# 28072  Visakhapatnam  2016-07-04    NaN    NaN    NaN    NaN    NaN    NaN
# 28073  Visakhapatnam  2016-07-05  17.00  68.00   7.32  25.08  17.66  15.80
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
vis_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5         230
# PM10          236
# NO            226
# NO2           248
# NOx            38
# NH3           213
# CO             39
# SO2           227
# O3            229
# Benzene        38
# Toluene        38
# Xylene         38
# AQI           291
# AQI_Bucket    291
# dtype: int64

# %%
vis_df.interpolate(limit_direction = "both",inplace=True)
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_25052\4048876413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vis_df.interpolate(limit_direction = "both",inplace=True)

# %%
vis_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5           0
# PM10            0
# NO              0
# NO2             0
# NOx             0
# NH3             0
# CO              0
# SO2             0
# O3              0
# Benzene         0
# Toluene         0
# Xylene          0
# AQI             0
# AQI_Bucket    291
# dtype: int64

# %% [markdown]
# ### Now for Delhi

# %%
delhi_bool = air_quality_df.City=="Delhi"

# %%
delhi_bool
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29526    False
# 29527    False
# 29528    False
# 29529    False
# 29530    False
# Name: City, Length: 29531, dtype: bool

# %%
delhi_df = air_quality_df[delhi_bool]

# %%
delhi_df
# Out:
#         City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 10229  Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 10230  Delhi  2015-01-02  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 10231  Delhi  2015-01-03   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 10232  Delhi  2015-01-04  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 10233  Delhi  2015-01-05  146.60  219.13  14.01  34.92   38.25  122.88   9.20
# ...      ...         ...     ...     ...    ...    ...     ...     ...    ...
# 12233  Delhi  2020-06-27   39.80  155.94  10.88  21.46   22.47   31.43   0.87
# 12234  Delhi  2020-06-28   59.52  308.65  12.67  21.60   23.86   29.27   0.94
# 12235  Delhi  2020-06-29   44.86  184.12  10.50  21.57   21.94   27.97   0.88
# 12236  Delhi  2020-06-30   39.80   91.98   5.99  17.96   15.44   28.48   0.84
# 12237  Delhi  2020-07-01   54.01  128.66   6.33  21.05   16.81   29.06   0.97
#
# ...

# %%
delhi_df.isnull().sum()
# Out:
# City            0
# Date            0
# PM2.5           2
# PM10           77
# NO              2
# NO2             2
# NOx             0
# NH3             9
# CO              0
# SO2           110
# O3             84
# Benzene         0
# Toluene         0
# Xylene        781
# AQI            10
# AQI_Bucket     10
# dtype: int64

# %%
delhi_df.interpolate(limit_direction='both',inplace=True)
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_25052\955042374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delhi_df.interpolate(limit_direction='both',inplace=True)

# %%
delhi_df.isnull().sum()
# Out:
# City           0
# Date           0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# CO             0
# SO2            0
# O3             0
# Benzene        0
# Toluene        0
# Xylene         0
# AQI            0
# AQI_Bucket    10
# dtype: int64

# %% [markdown]
# #### Converting the Date column as date format instead of objext format

# %%
hyd_df['Date'] = pd.to_datetime(hyd_df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
delhi_df['Date'] = pd.to_datetime(delhi_df['Date'])
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_25052\4279853289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delhi_df['Date'] = pd.to_datetime(delhi_df['Date'])

# %%
vis_df['Date'] = pd.to_datetime(vis_df['Date'])
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_25052\2046221346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vis_df['Date'] = pd.to_datetime(vis_df['Date'])

# %% [markdown]
# #### Converting the Date column into a index without which the resampling wont work

# %%
hyd_df.set_index('Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25052\820050429.py in <module>
# ----> 1 hyd_df.set_index('Date', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
delhi_df.set_index('Date',inplace=True)

# %%
vis_df.set_index('Date',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25052\723647955.py in <module>
# ----> 1 vis_df.set_index('Date',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %% [markdown]
# #### We are regroup the data Based on the month and taking the columns as their averages

# %%
hyd_monthly_df = hyd_df.resample('M').mean()
delhi_monthly_df = delhi_df.resample("M").mean()
vis_monthly_df = vis_df.resample("M").mean()

# %%
delhi_monthly_df
# Out:
#                  PM2.5        PM10         NO        NO2        NOx  \
# Date
# 2015-01-31  175.690645  276.971290  26.392581  36.925484  51.794194
# 2015-02-28  153.920357  234.939643  29.287857  41.656786  54.208571
# 2015-03-31   80.338065  135.044516  15.010000  24.386129  30.734194
# 2015-04-30   91.562333  187.991333  18.510667  44.279667  54.751000
# 2015-05-31   97.109355  271.050645  30.833871  61.483548  78.628065
# ...                ...         ...        ...        ...        ...
# 2020-03-31   57.506452  122.189032  21.949677  33.779355  38.555484
# 2020-04-30   44.940000  104.877667   9.710000  21.008333  20.548000
# 2020-05-31   55.448710  137.662258   9.770323  24.903871  22.486774
# 2020-06-30   46.694667  121.209333   8.458667  23.726667  21.125667
# 2020-07-31   54.010000  128.660000   6.330000  21.050000  16.810000
#
#                   NH3         CO        SO2         O3   Benzene    Toluene  \
# Date
# ...

# %% [markdown]
# ### What is  the Effect of LockDown on the air pollution
# #### As we know lockdown was implemented late 2019 and 2020

# %%
sns.set_style("whitegrid")

# %%
plt.plot(hyd_monthly_df.index,hyd_monthly_df.CO)
plt.plot(hyd_monthly_df.index,hyd_monthly_df.NO)
#plt.plot(hyd_monthly_df.index,hyd_monthly_df.O3)
plt.xlabel("Date")
plt.ylabel("Gas")
plt.legend(["CO","NO"])

# %%
#plt.plot(hyd_monthly_df.index,hyd_monthly_df.CO)
plt.plot(delhi_monthly_df.index,delhi_monthly_df.CO)
#plt.plot(vis_df.index,vis_df.CO)
plt.xlabel("Date")
plt.ylabel("Gas")
#plt.legend(["hyd","delhi","Vishakapatanam"])
# Out:
# Text(0, 0.5, 'Gas')

# %%
#plt.plot(hyd_monthly_df.index,hyd_monthly_df.CO)
#plt.plot(delhi_df.index,delhi_df.CO)
plt.plot(vis_monthly_df.index,vis_monthly_df.CO)
plt.xlabel("Date")
plt.ylabel("Gas")
#plt.legend(["hyd","delhi","Vishakapatanam"])
# Out:
# Text(0, 0.5, 'Gas')

# %% [markdown]
# #### From Above graphs we can infer that during lockdown though there was no use of vechiles the levels of CO were not really changes alot

# %% [markdown]
# ### Rank the cites based on their pollution levels

# %%
plt.plot(hyd_monthly_df.index,hyd_monthly_df.CO, '--')
plt.plot(delhi_monthly_df.index,delhi_monthly_df.CO,)
plt.plot(vis_monthly_df.index,vis_monthly_df.CO,'--')
plt.xlabel("Date")
plt.ylabel("Gas")
plt.legend(["Hyd","Delhi","Vishka"])

# %% [markdown]
# ####  Delhi >>> Hyd >> Vishaka

# %% [markdown]
# ### What is the effect of festivals like Diwali on pollution

# %%
plt.plot(hyd_monthly_df.index,hyd_monthly_df.PM10, '--')
plt.plot(delhi_monthly_df.index,delhi_monthly_df.PM10)
plt.plot(vis_monthly_df.index,vis_monthly_df.PM10,'--')
plt.xlabel("Date")
plt.ylabel("PM10")
plt.legend(["Hyd","Delhi","Vishka"])

# %% [markdown]
# We can this question from above graph diwali is usually celecbrated around november and there seems to sudden increse in pollution those months

# %% [markdown]
# ### what is Patteren of PM2.5 in different cites ?

# %%
plt.plot(hyd_monthly_df.index,hyd_monthly_df["PM2.5"], '--')
plt.plot(delhi_monthly_df.index,delhi_monthly_df['PM2.5'])
plt.plot(vis_monthly_df.index,vis_monthly_df['PM2.5'],'--')
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.legend(["Hyd","Delhi","Vishka"])

# %% [markdown]
# #### As we can see from the above graph PM2.5 changes seasonally , It is peak in winter months like jan ,nov ,dec ,jan, feb
# ####  Comparatively high in nov 2016 --> Hyderabad
# ####                                         nov 2017 --> Delh
# ####                                         nov 2019 --> Vishaka

# %% [markdown]
# ### what is Ozone levels like in these places

# %%
plt.plot(hyd_monthly_df.index,hyd_monthly_df["O3"], '--')
plt.plot(delhi_monthly_df.index,delhi_monthly_df['O3'])
plt.plot(vis_monthly_df.index,vis_monthly_df['O3'],'--')
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.legend(["Hyd","Delhi","Vishka"])

# %%
sns.scatterplot(x=hyd_monthly_df.index,y=hyd_monthly_df["O3"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='O3'>
